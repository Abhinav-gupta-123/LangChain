# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.chat_models import ChatOllama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
model=ChatOllama(model='llama3.2')
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_6724\674986822.py:1: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import ChatOllama``.
#   model=ChatOllama(model='llama3.2')

# %%
prompt = PromptTemplate(
    template='Answer the following question \n {question} from the following text - \n {text}',
    input_variables=['question','text']
)

# %%
parser = StrOutputParser()

# %%
url = 'https://en.wikipedia.org/wiki/MacBook_Air'
loader = WebBaseLoader(url)

# %%
docs = loader.load()

# %%
print(docs[0].page_content)
# Out:
# MacBook Air - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload fileSpecial pages
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Appearance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Donate
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
# Donate Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1
# Intel-based
#
#
#
#
# Toggle Intel-based subsection
#
#
#
#
#
# 1.1
# Unibody (2008–2009)
#
#
#
#
#
#
#
#
# 1.2
# ...

# %%
chain = prompt | model | parser

# %%
result=chain.invoke({'question':'What is the prodcut that we are talking about?', 'text':docs[0].page_content})

# %%
print(result)
# Out:
# It appears that you provided a large amount of text from Wikipedia, specifically about Apple and MacBooks. The text includes information on:
#
# * MacBook Air
# * Steve Jobs
# * Apple Inc.
# * History of Apple
# * Executives of Apple
# * Products introduced by Apple
# * Authority control databases
#
# However, it seems that the main topic is the MacBook Air laptop, which was first introduced in 2008.
#
# Here are some key points about the MacBook Air:
#
# * First released in June 2008 as a replacement for the PowerBook G4
# * Original price: $1,799 (8GB RAM, 80GB hard drive)
# * Designed by Intel and Apple, with a focus on energy efficiency and portability
# * Featured a 13.3-inch widescreen display, multi-touch trackpad, and 60W MagSafe power adapter
#
# If you would like to know more about the MacBook Air or its specifications, I can try to provide that information for you.

# %% [markdown]
# So,here we can get the data by directly use the url of website actually the webbaseloader use beutiful soup

# %% [markdown]
# If we want ,we can also make our dataset for further ussage using this with output parser like
# pydantic or anyother
