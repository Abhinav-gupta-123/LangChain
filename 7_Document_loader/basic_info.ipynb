# %% [markdown]
# There are 100 of document loaders but these 4 are most commonly used document loaders
#
# In this notebook we will see the main concept of document loaders and about the types of document loader

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So,there can be many way to get the data or various sources of data like ,pdf,database,cloud,so langchain make this document object ,the main objective of this document is simple ,to formate any type of data in common formate using document object

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
