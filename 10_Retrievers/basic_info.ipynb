# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # what is Retrievers

# %% [markdown]
# # So basically it take the query from user then interact with data sources they can either be wikipedia retriever, vectore stores and other it scan the document find the most relevant document and send to us

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # There are multiple retrievers for different purposes

# %% [markdown]
# # wekipedia retriever

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This is wikipedia retriever

# %% [markdown]
# # How it is work

# %% [markdown]
# Basically when user give thier query it send to wekipedia api then it find some most relevant articles , as much i know these articles are not filter on the basis of sentiment here in backend they actually use some keyword mapping concept and then it return the document to the user this is one of the simple concept of retriever

# %% [markdown]
# ## MMR

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # It is different from normal retriever based on similarity search like vectore storem it is not work on similarity based concept it try to find out the best result for any query and if we want more then one answer so it try to give the answer which is different from each other or should not same in terms of thier meaning

# %% [markdown]
# # Multi-query retriever

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # So the main purpose of this retriever is to remove the embiguity
#
# sometimes user send the ambiguous query which can have multiple meaning so here
#
# first quesry send to LLM then LLM give number of meaning of that query of numbers of query then that those number of query get send to the retriever then each retriever give some output for each query then it give the final number of query we want after using some filter like should not similar in meaning and other

# %% [markdown]
# ## Contextual Compression Retriever

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So as we can see in our above image there is document and if user send the query "What is photosynthesis " then there is term in document so it will return full document that the main problem because in that document above nad below line are irrelevant still normal retriever send thsi document so here this contextual compression retriever scan this whole document and will send the only relevant line from that document
