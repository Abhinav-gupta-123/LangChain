# %% [markdown]
# ![](attachment:image.png)

# %% [markdown]
# To use the chains we need to know about runnables first

# %% [markdown]
# Why runnables introduced?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So,when langchain started to indroducing thier multiple chains ,at that time there is one major problem, the problem is (the different components are not compatible with each other ,and dont follow the same standered) like llm when we need to get output we use ("llm.predict()") but when we need to use the formated prompt we use("prompt.formate()") so both use different way to perform their task that's why langchain make so many different chain by written manually functions and after sometime they realise they make a huge mistake then they decide to make them again and decide to ensure the new component should be standardized and can connect smoothly with each other and this is possible with ("RUNNABLES")

# %% [markdown]
# # With use of runnables we can make any type of complex chain

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  ![image.png](attachment:image.png)

# %% [markdown]
# As we already implemented this in out previous notebooks with simple chains like
#
# chain= prompt | model | parser

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We already used some of them in our previous notebooks,for more info refer to the official documentation of langchain on their official site
