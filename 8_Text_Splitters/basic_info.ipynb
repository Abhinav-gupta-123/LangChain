# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Length based text splitting, it is very simple to implement, basically here we itterate the text and let suppose we have to make the chunks of 100 character each so here we will iterate it and make the chunks ,here we take the example of character we can also make on the basis of embeddings or tokens,its biggest disadvantage is it doesn't care about language,text grammer meaning,sementic meaning and all
