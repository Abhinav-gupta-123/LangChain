# %%
from langchain_experimental.text_splitter import SemanticChunker
from langchain.embeddings import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

text_splitter = SemanticChunker(
    embedding_model,
    breakpoint_threshold_type="percentile",
    breakpoint_threshold_amount=50 # 👈 This means: split at top 40% semantic changes
)

sample = """
Farmers were working hard in the fields, preparing the soil and planting seeds for the next season. The sun was bright, and the air smelled of earth and fresh grass. The Indian Premier League (IPL) is the biggest cricket league in the world. People all over the world watch the matches and cheer for their favourite teams.


Terrorism is a big danger to peace and safety. It causes harm to people and creates fear in cities and villages. When such attacks happen, they leave behind pain and sadness. To fight terrorism, we need strong laws, alert security forces, and support from people who care about peace and safety.
"""

docs = text_splitter.create_documents([sample])

# Output the results
print(f"Chunks: {len(docs)}")
for i, doc in enumerate(docs):
    print(f"\nChunk {i+1}:\n{doc.page_content.strip()}")
# Out:
# Requirement already satisfied: langchain-experimental in c:\users\abhin\desktop\.venv\lib\site-packages (0.3.4)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-experimental) (0.3.22)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.28 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-experimental) (0.3.55)
# Requirement already satisfied: langchain<1.0.0,>=0.3.24 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.24)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.0.38)
# Requirement already satisfied: requests<3,>=2 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.11.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.32)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\abhin\desktop\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\abhin\desktop\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\abhin\desktop\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain<1.0.0,>=0.3.24->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain<1.0.0,>=0.3.24->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\abhin\desktop\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\abhin\desktop\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.28->langchain-experimental) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\abhin\desktop\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.23.0)
# Requirement already satisfied: anyio in c:\users\abhin\desktop\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (4.8.0)
# Requirement already satisfied: certifi in c:\users\abhin\desktop\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\abhin\desktop\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.7)
# Requirement already satisfied: idna in c:\users\abhin\desktop\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\abhin\desktop\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.24->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\abhin\desktop\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.24->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhin\desktop\.venv\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abhin\desktop\.venv\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\abhin\desktop\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\abhin\desktop\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\abhin\desktop\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Chunks: 5
#
# Chunk 1:
# Farmers were working hard in the fields, preparing the soil and planting seeds for the next season.
#
# Chunk 2:
# The sun was bright, and the air smelled of earth and fresh grass. The Indian Premier League (IPL) is the biggest cricket league in the world. People all over the world watch the matches and cheer for their favourite teams.
#
# Chunk 3:
# Terrorism is a big danger to peace and safety.
#
# Chunk 4:
# It causes harm to people and creates fear in cities and villages. When such attacks happen, they leave behind pain and sadness. To fight terrorism, we need strong laws, alert security forces, and support from people who care about peace and safety.
#
# Chunk 5:
